# %% [markdown]
# # Nota-Saving Tool com Pydantic e Anthropic Tool Use
#
# In Este exemplo, we'll criar a tool aquele saves a Nota com the author e metadata, e use Pydantic para validar the model's resposta quando calling the tool. We'll define the necessary Pydantic models, processo the tool call, e ensure aquele the model's resposta conforms para the expected schema.

# %% [markdown]
# ## Step 1: Set up the environment
# primeiro, let's instalar the obrigatório libraries e set up the Anthropic API cliente.

# %%
# %pip install anthropic pydantic 'pydantic[email]'

# %%
from anthropic import Anthropic
from pydantic import BaseModel, EmailStr, Field
from typing import Optional

client = Anthropic()
MODEL_NAME = "claude-3-opus-20240229"

# %% [markdown]
# ## Step 2: Define the Pydantic models
#
# We'll define Pydantic models para represent the expected schema for the Nota, author, e the model's resposta. este will allow us para validar e type-verificar the model's resposta quando saving a Nota.

# %%
class Author(BaseModel):
    name: str
    email: EmailStr

class Note(BaseModel):
    note: str
    author: Author
    tags: Optional[list[str]] = None
    priority: int = Field(ge=1, le=5, default=3)
    is_public: bool = False

class SaveNoteResponse(BaseModel):
    success: bool
    message: str

# %% [markdown]
# ## Step 3: Define the cliente-side tool
#
# próximo, we'll define the cliente-side tool aquele our chatbot will use para salvar notes.

# %%
tools = [
    {
        "name": "save_note",
        "description": "A tool that saves a note with the author and metadata.",
        "input_schema": {
            "type": "object",
            "properties": {
                "note": {
                    "type": "string",
                    "description": "The content of the note to be saved."
                },
                "author": {
                    "type": "object",
                    "properties": {
                        "name": {
                            "type": "string",
                            "description": "The name of the author."
                        },
                        "email": {
                            "type": "string",
                            "format": "email",
                            "description": "The email address of the author."
                        }
                    },
                    "required": ["name", "email"]
                },
                "priority": {
                    "type": "integer",
                    "minimum": 1,
                    "maximum": 5,
                    "default": 3,
                    "description": "The priority level of the note (1-5)."
                },
                "is_public": {
                    "type": "boolean",
                    "default": False,
                    "description": "Indicates whether the note is publicly accessible."
                }
            },
            "required": ["note", "author"]
        }
    }
]

# %% [markdown]
# ## Step 4: Implement the Nota-saving tool
# We'll criar a dummy Nota saving função aquele just prints out aquele the Nota was saved successfully. se you actually want este Nota para be saved em algum lugar, you can implement este função.

# %%
def save_note(note: str, author: dict, priority: int = 3, is_public: bool = False) -> None:
    print("Note saved successfully!")

# %% [markdown]
# ## Step 5: processo the tool call e generate the resposta
# We'll criar funções para processo the tool call made by Claude e generate the resposta indicating the sucesso of saving the Nota.

# %%
def process_tool_call(tool_name, tool_input):
    if tool_name == "save_note":
        note = Note(
            note=tool_input["note"],
            author=Author(
                name=tool_input["author"]["name"],
                email=tool_input["author"]["email"]
            ),
            priority=tool_input.get("priority", 3),
            is_public=tool_input.get("is_public", False)
        )
        save_note(note.note, note.author.model_dump(), note.priority, note.is_public)
        return SaveNoteResponse(success=True, message="Note saved successfully!")

def generate_response(save_note_response):
    return f"Response: {save_note_response.message}"

# %% [markdown]
# ## Step 6: Interact com the chatbot
#
# agora, let's criar a função para interact com the chatbot. We'll enviar a usuário message, processo the tool call made by Claude, generate the resposta, validar the model's resposta using Pydantic, e retorna the final resposta para the usuário.

# %%
def chatbot_interaction(user_message):
    print(f"\n{'='*50}\nUser Message: {user_message}\n{'='*50}")

    messages = [
        {"role": "user", "content": user_message}
    ]

    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=4096,
        tools=tools,
        messages=messages
    )

    print(f"\nInitial Response:")
    print(f"Stop Reason: {message.stop_reason}")
    print(f"Content: {message.content}")

    if message.stop_reason == "tool_use":
        tool_use = next(block for block in message.content if block.type == "tool_use")
        tool_name = tool_use.name
        tool_input = tool_use.input

        print(f"\nTool Used: {tool_name}")
        print(f"Tool Input: {tool_input}")

        save_note_response = process_tool_call(tool_name, tool_input)


        print(f"Tool Result: {save_note_response}")

        response = client.messages.create(
            model=MODEL_NAME,
            max_tokens=4096,
            messages=[
                {"role": "user", "content": user_message},
                {"role": "assistant", "content": message.content},
                {
                    "role": "user",
                    "content": [
                        {
                            "type": "tool_result",
                            "tool_use_id": tool_use.id,
                            "content": str(save_note_response),
                        }
                    ],
                },
            ],
            tools=tools,
        )
    else:
        response = message

    final_response = next(
        (block.text for block in response.content if hasattr(block, "text")),
        None,
    )
    print(response.content)
    print(f"\nFinal Response: {final_response}")

    return final_response

# %% [markdown]
# ## Step 7: teste the chatbot
# Let's teste our chatbot com a sample query para salvar a Nota.

# %%
chatbot_interaction("""
Can you save a private note with the following details?
Note: Remember to buy milk and eggs.
Author: John Doe (johndoe@gmail.com)
Priority: 4
""")
# Out:
# ...
# User Message:
# Can you save a private note with the following details?
# Note: Remember to buy milk and eggs.
# Author: John Doe (johndoe@gmail.com)
# Priority: 4
#
# ...
#
# Initial Response:
# Stop Reason: tool_use
# ...

# %% [markdown]
# In Este exemplo, we've created a tool aquele saves a Nota com the author e metadata. The chatbot uses the save_note tool para salvar the Nota, e Pydantic is used para validar the model's resposta quando calling the tool. The Nota, Author, e SaveNoteResponse models ensure aquele the tool entrada e the model's resposta conform para the expected schema.
#
# By defining limpar Pydantic models e using them para validar the model's resposta, we adicionar an extra layer of confiabilidade e safety quando interacting com the chatbot e saving notes.
